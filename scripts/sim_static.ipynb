# %%
from gurobipy import *
from math import *
from random import randint
import sys
import random
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
from openpyxl.workbook import Workbook

# %%
################################################################
## INPUT FILES
################################################################
#instances = range(1,11) # instance number
network = '43' #number of links or name of the network

network_file = 'Network' + network + '.xlsx'
inst_file = 'Instance26week.xlsx'
arrivals = 'admit.xlsx'
tot_days = 26*7

# %%
################################################################
## READ IN DATA FROM FILES
################################################################
df_I = pd.read_excel(inst_file, sheet_name='ICU') # data frame of ICU
df_J = pd.read_excel(inst_file, sheet_name='DSU') # data frame of DSU
df_G = pd.read_excel(network_file, sheet_name='Network') # data frame network
df_A = pd.read_excel(arrivals) # data frame arrivals

I = df_I['ICU name'].tolist() # ICU list
J = df_J['DSU name'].tolist() # DSU list

C_bar = df_I.set_index('ICU name')['Capacity'].to_dict() # total ICU capacity
P_init = df_I.set_index('ICU name')['O1'].to_dict() # initial patient occupancy at ICU

D_bar = df_J.set_index('DSU name')['Capacity'].to_dict() # total DSU capacity
D_prime_bar = df_J.set_index('DSU name')['Variable capacity'].to_dict() # total DSU flexible capacity
Q_init = df_J.set_index('DSU name')['O1'].to_dict() # initial occupancy at DSU
Q_prime_init = df_J.set_index('DSU name')['O1_vc'].to_dict()

Ji = {} # list of feasible DSUs for each ICU
for i in I:
    df_G_i = df_G[df_G['ICU'] == i]
    Ji[i] = df_G_i['DSU'].tolist()

Ij = {} # list of feasible ICUs for each DSU
for j in J:
    df_G_j = df_G[df_G['DSU'] == j]
    Ij[j] = df_G_j['ICU'].tolist()
# Out:
# [u'10W', u'10E', u'RPRE', u'8D', u'5D', u'10D', u'11N', u'12S', u'7F', u'4D', u'9G', u'12N', u'5G', u'R7SN', u'7D', u'10S', u'6D', u'3E', u'12D', u'9N', u'8G', u'10G', u'7G', u'10N', u'9D', u'8W', u'8N', u'R7SS'] 28

# %%
tempJ = []
for j in J:
    if len(Ij[j]) > 0:
        tempJ.append(j)
J = tempJ
# Out:
# [u'8D', u'5D', u'10D', u'11N', u'12S', u'7F', u'4D', u'9G', u'12N', u'5G', u'7D', u'10S', u'6D', u'3E', u'12D', u'10G', u'10N', u'9D'] 18

# %%
################################################################
## PARAMETERS
################################################################

b = {} # Price for flexible capacity
for j in J:
    b[j] = 0.001 # for simple example
    
l = {} # Initial guess for lambda prices out of ICUs
for i in I:
    l[i] = 0.1
    
iter = 100 # Loop iterations
step = 0.001

# %%
def U(a,y):
    ''' Utility function
        '''
    return 1-exp(-a*y)

def ICU(a,C,lam):
    ''' A function that solves the ICU problem and returns the
        value of y
        '''
    y = {}
    y0 = {}
    y1 = {}
    y2 = {}
    y3 = {}
    for i in I:
        if lam[i] <= 0:
            y[i] = C[i]
        else:
            y0[i] = 0
            y3[i] = C[i]
            stat_point = (-1/float(a[i]))*log(lam[i]/float(a[i]))
            y1[i] = floor(stat_point)
            y2[i] = ceil(stat_point)
            Obj = {}
            Obj[y0[i]] = U(a[i], y0[i]) - lam[i]*y0[i]
            Obj[y3[i]] = U(a[i], y3[i]) - lam[i]*y3[i]
            if y1[i] >= 0 and y1[i] <= C[i]:
                Obj[y1[i]] = U(a[i], y1[i]) - lam[i]*y1[i]
            if y2[i] >= 0 and y2[i] <= C[i]:
                Obj[y2[i]] = U(a[i], y2[i]) - lam[i]*y2[i]
            y[i] = max(Obj.iteritems(), key=operator.itemgetter(1))[0]
    return y

def dualobj(a,x,z,y,lam):
    ''' A function calculating the dual objective value for a given
    price and solutions x, z, y
    '''
    v = sum(U(a[i],y[i]) - lam[i]*y[i] for i in I) + sum(sum(lam[i]*x[i,j] + (lam[i]-b[j])*z[i,j] for j in Ji[i]) for i in I)
    return v

def netLP(C,D,D_prime,lam,nu):
    ''' A function that solves the network LP for a given price vector p and returns the
        values of x and z'''
    m = Model()
    x = {}
    z = {}
    d = {}
    for i in I:
        for j in Ji[i]:
            x[i,j] = m.addVar(lb = 0, ub = C[i], vtype = GRB.CONTINUOUS, name = "x[%s,%s]" % (i,j))
            z[i,j] = m.addVar(lb = 0, ub = C[i], vtype = GRB.CONTINUOUS, name = "z[%s,%s]" % (i,j))
    
    m.update()
    m.setObjective(sum(sum(lam[i]*x[i,j] + (lam[i]-b[j])*z[i,j] for j in Ji[i]) for i in I), GRB.MAXIMIZE)
    for j in J:
        m.addConstr(sum(x[i,j] for i in Ij[j]) <= D[j])
        m.addConstr(sum(z[i,j] for i in Ij[j]) <= D_prime[j])

    m.addConstr(sum(sum(z[i,j] for j in Ji[i]) for i in I) <= nu)

    m.optimize()
    xs = {}
    zs = {}
    for i in I:
        for j in Ji[i]:
            xs[i,j] = m.getVarByName('x[%s,%s]' % (i,j)).x
            zs[i,j] = m.getVarByName('z[%s,%s]' % (i,j)).x
    return xs, zs

# %%
def findLambda(a,nu,C,D,D_prime):
    # Subgradient algorithm 
    grad = {}
    pr = {}
    xk = {}
    zk = {}
    yk = {}
    objk = {}

    pr[0] = l #initial guess
    xk[0], zk[0] = netLP(C,D,D_prime,pr[0],nu)
    yk[0] = ICU(a,C,pr[0])

    grad[0] = {}
    for i in I:
        grad[0][i] = sum((xk[0][i,j] + zk[0][i,j]) for j in Ji[i]) - yk[0][i]

    objk[0] = dualobj(a,xk[0],zk[0],yk[0],pr[0])
    q_best = objk[0]

    iter_tobest = 0

    p_best = pr[0]
    x_best = xk[0]
    z_best = zk[0]
    y_best = yk[0]


    for k in range(1,iter+1):

        # Candidate price, x, z, and y
        p = {}
        for i in I:
            p[i] = pr[k-1][i] - (step/sqrt(k))*grad[k-1][i]

        x, z = netLP(C,D,D_prime,p,nu)
        y = ICU(a,C,p)
        g = {}
        for i in I:
            g[i] = sum((x[i,j] + z[i,j]) for j in Ji[i]) - y[i]

        q = dualobj(a,x,z,y,p)

        pr[k] = p
        xk[k] = x
        zk[k] = z
        yk[k] = y
        grad[k] = g
        objk[k] = q

        if q <= q_best: # if improvement, update
            q_best = objk[k]
            p_best = pr[k]
            x_best = xk[k]
            z_best = zk[k]
            y_best = yk[k]
            iter_tobest = k
    
    return p_best

# %%
##################################################################
def policyOPT(a,nu,C,D,D_prime):
    
    u = {}
    for i in I:
        for k in range(C[i]+1):
            u[i,k] = 1-exp(-a[i]*k)
    
    m = Model()
    x = {}
    z = {}
    y = {}
    for i in I:
        for j in Ji[i]:
            x[i,j] = m.addVar(lb = 0, vtype = GRB.INTEGER, name = "x[%s,%s]" % (i,j))
            z[i,j] = m.addVar(lb = 0, vtype = GRB.INTEGER, name = "z[%s,%s]" % (i,j))
        for k in range(C[i]+1):
            y[i,k] = m.addVar(lb = 0, vtype = GRB.BINARY, name = "y[%s,%s]" % (i,k))
            
    m.update()
    m.setObjective(sum(sum(u[i,k]*y[i,k] for k in range(C[i]+1)) for i in I) - sum(b[j]*sum(z[i,j] for i in Ij[j]) for j in J), GRB.MAXIMIZE)
        
    for i in I:
        m.addConstr(sum(x[i,j]+z[i,j] for j in Ji[i]) == sum(k*y[i,k] for k in range(C[i]+1)))
        m.addConstr(sum(y[i,k] for k in range(C[i]+1)) == 1)
    
    for j in J:
        m.addConstr(sum(x[i,j] for i in Ij[j]) <= D[j])
        m.addConstr(sum(z[i,j] for i in Ij[j]) <= D_prime[j])
    m.addConstr(sum(sum(z[i,j] for j in Ji[i]) for i in I) <= nu)

    m.optimize()
    xs = {}
    zs = {}
    ys = {}

    for i in I:
        for j in Ji[i]:
            xs[i,j] = m.getVarByName('x[%s,%s]' % (i,j)).x
            zs[i,j] = m.getVarByName('z[%s,%s]' % (i,j)).x
        for k in range(C[i]+1):
            ys[i,k] = m.getVarByName('y[%s,%s]' % (i,k)).x

    return xs, zs

# %%
C_inst = {}
A_icu = {}
A_dsu = {}
Disch = {}
Disch_vc = {}
x = {}
z = {}

for day in range(1,tot_days+1):
    C_inst[day] = df_I.set_index('ICU name')['C'+str(day)].to_dict()
    A_icu[day] = df_I.set_index('ICU name')['A'+str(day)].to_dict()
    A_dsu[day] = df_J.set_index('DSU name')['A'+str(day)].to_dict()
    Disch[day] = df_J.set_index('DSU name')['C'+str(day)].to_dict()
    Disch_vc[day] = df_J.set_index('DSU name')['C_vc'+str(day)].to_dict()
    
nu_max = 100

# %%
################################################################
## TRANSITION FUNCTION
################################################################
def trans_func(day, P0, Q0, Q_prime0, nu0):
    '''A function to determine the transitions from one state to the next
        '''
    # Read transfer requests and new arrivals for the given day
    d = day%7
    if d == 0:
        d = 7
    a = {}
    for i in I:
        a[i] = df_A.loc[i, d]/10.0

    C = {}
    for i in I:
        C[i] = int(min(C_inst[day][i], P0[i]))    
    D = {}
    D_prime = {}
    for j in J:
        D[j] = D_bar[j]-Q0[j]
        D_prime[j] = D_prime_bar[j]-Q_prime0[j]
    #lam = findLambda(a,nu0,C,D,D_prime)
    
    # 1) Make transfer decisions given the state
    x, z = policyOPT(a,nu0,C,D,D_prime)
    
    # 2) Update the ICU populations by removing transfers and admitting new arrivals
    P1 = {}
    lost_icu = {}
    for i in I:
        P1[i] = min(P0[i]-sum(x[i,j]+z[i,j] for j in Ji[i])+A_icu[day][i], C_bar[i])
        lost_icu[i] = max(0, P0[i]-sum(x[i,j]+z[i,j] for j in Ji[i])+A_icu[day][i] - C_bar[i])
        
    # 3) Update the DSU populations by
        # a) adding transfers b) discharging patients c) admitting new arrivals
    Q1 = {}
    Q1_prime = {}
    lost_dsu = {}

    for j in J:
        # a) add transfers 
        population = Q0[j] + sum(x[i,j] for i in Ij[j])
        population_vc = Q_prime0[j] + sum(z[i,j] for i in Ij[j])
        
        # b) discharge patients
        population = max(0, population - Disch[day][j])
        population_vc = max(0, population_vc - Disch_vc[day][j])
        
        # c) admit new arrivals
        Q1[j] = min(population + A_dsu[day][j], D_bar[j])
        lost_dsu[j] = max(0, population + A_dsu[day][j] - D_bar[j])
        Q1_prime[j] = population_vc
        
        
    nu1 = max(0,nu_max - sum(Q1_prime[j] for j in J))
    
    o = sum(U(a[i], sum(x[i,j] for j in Ji[i])) for i in I) - sum(b[j]*sum(z[i,j] for i in Ij[j]) for j in J)
    
    return P1, Q1, Q1_prime, nu1, x, z, lost_icu, lost_dsu, o

# %%
#day = 1 # Monday
P = {}
P[0] = df_I.set_index('ICU name')['O1'].to_dict() 

Q = {}
Q[0] = df_J.set_index('DSU name')['O1'].to_dict() 

Q_prime = {}
Q_prime[0] = df_J.set_index('DSU name')['O1_vc'].to_dict() 

nu = {}
nu[0] = sum(Q_prime[0][j] for j in J) + int((sum(D_prime_bar[j] for j in J))/2)

# %%
L_icu = {}
L_dsu = {}
o = {}

for day in range(1,tot_days+1):
    P[day], Q[day], Q_prime[day], nu[day], x[day], z[day], L_icu[day], L_dsu[day], o[day] = trans_func(day, P[day-1], Q[day-1], Q_prime[day-1], nu[day-1])
# Out:
# Academic license - for non-commercial use only
# Optimize a model with 71 rows, 203 columns and 432 nonzeros
# Variable types: 0 continuous, 203 integer (117 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 34 rows and 87 columns
# Presolve time: 0.00s
# Presolved: 37 rows, 116 columns, 230 nonzeros
# Found heuristic solution: objective 6.0586547
# Variable types: 0 continuous, 116 integer (73 binary)
#
# Root relaxation: objective 1.113238e+01, 24 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      11.1323834   11.13238  0.00%     -    0s
#
# Explored 0 nodes (24 simplex iterations) in 0.14 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 11.1324 6.05865 4.33402
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.113238338130e+01, best bound 1.113238338130e+01, gap 0.0000%
# Optimize a model with 71 rows, 197 columns and 420 nonzeros
# Variable types: 0 continuous, 197 integer (111 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 23 rows and 67 columns
# Presolve time: 0.00s
# Presolved: 48 rows, 130 columns, 291 nonzeros
# Found heuristic solution: objective 3.0009678
# Variable types: 0 continuous, 130 integer (87 binary)
#
# Root relaxation: objective 7.758219e+00, 36 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.7582192    7.75822  0.00%     -    0s
#
# Explored 0 nodes (36 simplex iterations) in 0.19 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 7.75822 3.00097 0.483989
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.758219160131e+00, best bound 7.758219160131e+00, gap 0.0000%
# Optimize a model with 71 rows, 203 columns and 432 nonzeros
# Variable types: 0 continuous, 203 integer (117 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 18 rows and 62 columns
# Presolve time: 0.00s
# Presolved: 53 rows, 141 columns, 308 nonzeros
# Variable types: 0 continuous, 141 integer (96 binary)
#
# Root relaxation: objective 8.588029e+00, 41 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       8.5880294    8.58803  0.00%     -    0s
#
# Explored 0 nodes (41 simplex iterations) in 0.21 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 8.58803 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.588029359836e+00, best bound 8.588029359836e+00, gap 0.0000%
# Optimize a model with 71 rows, 196 columns and 418 nonzeros
# Variable types: 0 continuous, 196 integer (110 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 29 rows and 89 columns
# Presolve time: 0.00s
# Presolved: 42 rows, 107 columns, 243 nonzeros
# Found heuristic solution: objective 3.5756314
# Variable types: 0 continuous, 107 integer (75 binary)
#
# Root relaxation: objective 6.573055e+00, 47 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.5730546    6.57305  0.00%     -    0s
#
# Explored 0 nodes (47 simplex iterations) in 0.17 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 6.57305 3.57563 1.1062
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.573054620738e+00, best bound 6.573054620738e+00, gap 0.0000%
# Optimize a model with 71 rows, 193 columns and 412 nonzeros
# Variable types: 0 continuous, 193 integer (107 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 25 rows and 73 columns
# Presolve time: 0.00s
# Presolved: 46 rows, 120 columns, 263 nonzeros
# Variable types: 0 continuous, 120 integer (88 binary)
#
# Root relaxation: objective 7.366915e+00, 43 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.3669147    7.36691  0.00%     -    0s
#
# Explored 0 nodes (43 simplex iterations) in 0.20 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.36691 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.366914714863e+00, best bound 7.366914714863e+00, gap 0.0000%
# Optimize a model with 71 rows, 184 columns and 394 nonzeros
# Variable types: 0 continuous, 184 integer (98 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 18 rows and 51 columns
# Presolve time: 0.00s
# Presolved: 53 rows, 133 columns, 297 nonzeros
# Variable types: 0 continuous, 133 integer (81 binary)
#
# Root relaxation: objective 7.039206e+00, 60 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.0392060    7.03921  0.00%     -    0s
#
# Explored 0 nodes (60 simplex iterations) in 0.16 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.03921 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.039205952781e+00, best bound 7.039205952781e+00, gap 0.0000%
# Optimize a model with 71 rows, 174 columns and 374 nonzeros
# Variable types: 0 continuous, 174 integer (88 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 23 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 48 rows, 109 columns, 251 nonzeros
# Variable types: 0 continuous, 109 integer (80 binary)
#
# Root relaxation: objective 4.075230e+00, 55 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       4.0752296    4.07523  0.00%     -    0s
#
# Explored 0 nodes (55 simplex iterations) in 0.19 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 4.07523 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.075229623960e+00, best bound 4.075229623960e+00, gap 0.0000%
# Optimize a model with 71 rows, 204 columns and 434 nonzeros
# Variable types: 0 continuous, 204 integer (118 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 19 rows and 53 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 151 columns, 340 nonzeros
# Variable types: 0 continuous, 151 integer (109 binary)
#
# Root relaxation: objective 7.263973e+00, 64 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# *    0     0               0       7.2639730    7.26397  0.00%     -    0s
#
# Explored 0 nodes (64 simplex iterations) in 0.15 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.26397 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.263972987992e+00, best bound 7.263972987992e+00, gap 0.0000%
# Optimize a model with 71 rows, 201 columns and 428 nonzeros
# Variable types: 0 continuous, 201 integer (115 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 13 rows and 40 columns
# Presolve time: 0.00s
# Presolved: 58 rows, 161 columns, 359 nonzeros
# Variable types: 0 continuous, 161 integer (104 binary)
#
# Root relaxation: objective 8.956928e+00, 70 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       8.9569280    8.95693  0.00%     -    0s
#
# Explored 0 nodes (70 simplex iterations) in 0.15 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 8.95693 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.956927969143e+00, best bound 8.956927969143e+00, gap 0.0000%
# Optimize a model with 71 rows, 196 columns and 418 nonzeros
# Variable types: 0 continuous, 196 integer (110 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 15 rows and 56 columns
# Presolve time: 0.00s
# Presolved: 56 rows, 140 columns, 316 nonzeros
# Variable types: 0 continuous, 140 integer (100 binary)
#
# Root relaxation: objective 7.406873e+00, 52 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.4068735    7.40687  0.00%     -    0s
#
# Explored 0 nodes (52 simplex iterations) in 0.15 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.40687 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.406873494331e+00, best bound 7.406873494331e+00, gap 0.0000%
# Optimize a model with 71 rows, 196 columns and 418 nonzeros
# Variable types: 0 continuous, 196 integer (110 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 20 rows and 66 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 130 columns, 289 nonzeros
# Variable types: 0 continuous, 130 integer (92 binary)
#
# Root relaxation: objective 7.383249e+00, 45 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.3832494    7.38325  0.00%     -    0s
#
# Explored 0 nodes (45 simplex iterations) in 0.12 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.38325 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.383249411296e+00, best bound 7.383249411296e+00, gap 0.0000%
# Optimize a model with 71 rows, 201 columns and 428 nonzeros
# Variable types: 0 continuous, 201 integer (115 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 24 rows and 70 columns
# Presolve time: 0.00s
# Presolved: 47 rows, 131 columns, 298 nonzeros
# Found heuristic solution: objective 3.1135439
# Variable types: 0 continuous, 131 integer (95 binary)
#
# Root relaxation: objective 7.042349e+00, 50 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.0423485    7.04235  0.00%     -    0s
#
# Explored 0 nodes (50 simplex iterations) in 0.17 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 7.04235 3.11354 0.365395
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.042348509228e+00, best bound 7.042348509228e+00, gap 0.0000%
# Optimize a model with 71 rows, 179 columns and 384 nonzeros
# Variable types: 0 continuous, 179 integer (93 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 25 rows and 64 columns
# Presolve time: 0.00s
# Presolved: 46 rows, 115 columns, 254 nonzeros
# Found heuristic solution: objective 2.7317751
# Variable types: 0 continuous, 115 integer (75 binary)
#
# Root relaxation: objective 6.716918e+00, 40 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.7169181    6.71692  0.00%     -    0s
#
# Explored 0 nodes (40 simplex iterations) in 0.17 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 6.71692 2.73178 0.435822
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.716918137835e+00, best bound 6.716918137835e+00, gap 0.0000%
# Optimize a model with 71 rows, 183 columns and 392 nonzeros
# Variable types: 0 continuous, 183 integer (97 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 29 rows and 87 columns
# Presolve time: 0.00s
# Presolved: 42 rows, 96 columns, 216 nonzeros
# Found heuristic solution: objective 2.8111449
# Variable types: 0 continuous, 96 integer (68 binary)
#
# Root relaxation: objective 5.670213e+00, 41 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       5.6702130    5.67021  0.00%     -    0s
#
# Explored 0 nodes (41 simplex iterations) in 0.19 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 5.67021 2.81114 0.684493
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.670213038440e+00, best bound 5.670213038440e+00, gap 0.0000%
# Optimize a model with 71 rows, 192 columns and 410 nonzeros
# Variable types: 0 continuous, 192 integer (106 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 21 rows and 64 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 128 columns, 287 nonzeros
# Found heuristic solution: objective 2.9563196
# Variable types: 0 continuous, 128 integer (95 binary)
#
# Root relaxation: objective 6.409133e+00, 74 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.4091327    6.40913  0.00%     -    0s
#
# Explored 0 nodes (74 simplex iterations) in 0.17 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 6.40913 2.95632 0.182239
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.409132743505e+00, best bound 6.409132743505e+00, gap 0.0000%
# Optimize a model with 71 rows, 229 columns and 484 nonzeros
# Variable types: 0 continuous, 229 integer (143 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 25 rows and 73 columns
# Presolve time: 0.00s
# Presolved: 46 rows, 156 columns, 338 nonzeros
# Variable types: 0 continuous, 156 integer (118 binary)
#
# Root relaxation: objective 6.527263e+00, 58 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.5272635    6.52726  0.00%     -    0s
#
# Explored 0 nodes (58 simplex iterations) in 0.16 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.52726 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.527263471354e+00, best bound 6.527263471354e+00, gap 0.0000%
# Optimize a model with 71 rows, 201 columns and 428 nonzeros
# Variable types: 0 continuous, 201 integer (115 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 20 rows and 64 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 137 columns, 317 nonzeros
# Variable types: 0 continuous, 137 integer (103 binary)
#
# Root relaxation: objective 5.212654e+00, 71 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       5.2126538    5.21265  0.00%     -    0s
#
# Explored 0 nodes (71 simplex iterations) in 0.17 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 5.21265 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.212653754894e+00, best bound 5.212653754894e+00, gap 0.0000%
# Optimize a model with 71 rows, 205 columns and 436 nonzeros
# Variable types: 0 continuous, 205 integer (119 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 19 rows and 62 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 143 columns, 317 nonzeros
# Variable types: 0 continuous, 143 integer (103 binary)
#
# Root relaxation: objective 7.436464e+00, 74 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.4364643    7.43646  0.00%     -    0s
#
# Explored 0 nodes (74 simplex iterations) in 0.24 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.43646 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.436464341424e+00, best bound 7.436464341424e+00, gap 0.0000%
# Optimize a model with 71 rows, 220 columns and 466 nonzeros
# Variable types: 0 continuous, 220 integer (134 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 13 rows and 51 columns
# Presolve time: 0.00s
# Presolved: 58 rows, 169 columns, 369 nonzeros
# Variable types: 0 continuous, 169 integer (129 binary)
#
# Root relaxation: objective 7.713217e+00, 73 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.7132174    7.71322  0.00%     -    0s
#
# Explored 0 nodes (73 simplex iterations) in 0.20 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.71322 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.713217426383e+00, best bound 7.713217426383e+00, gap 0.0000%
# Optimize a model with 71 rows, 188 columns and 402 nonzeros
# Variable types: 0 continuous, 188 integer (102 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 27 rows and 78 columns
# Presolve time: 0.00s
# Presolved: 44 rows, 110 columns, 248 nonzeros
# Variable types: 0 continuous, 110 integer (78 binary)
#
# Root relaxation: objective 6.226785e+00, 36 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.2267851    6.22679  0.00%     -    0s
#
# Explored 0 nodes (36 simplex iterations) in 0.18 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.22679 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.226785069381e+00, best bound 6.226785069381e+00, gap 0.0000%
# Optimize a model with 71 rows, 185 columns and 396 nonzeros
# Variable types: 0 continuous, 185 integer (99 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 23 rows and 59 columns
# Presolve time: 0.00s
# Presolved: 48 rows, 126 columns, 279 nonzeros
# Variable types: 0 continuous, 126 integer (98 binary)
#
# Root relaxation: objective 5.037711e+00, 61 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       5.0377108    5.03771  0.00%     -    0s
#
# Explored 0 nodes (61 simplex iterations) in 0.15 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 5.03771 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.037710807592e+00, best bound 5.037710807592e+00, gap 0.0000%
# Optimize a model with 71 rows, 206 columns and 438 nonzeros
# Variable types: 0 continuous, 206 integer (120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 23 rows and 69 columns
# Presolve time: 0.00s
# Presolved: 48 rows, 137 columns, 308 nonzeros
# Variable types: 0 continuous, 137 integer (104 binary)
#
# Root relaxation: objective 5.504512e+00, 69 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       5.5045120    5.50451  0.00%     -    0s
#
# Explored 0 nodes (69 simplex iterations) in 0.14 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 5.50451 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.504512036811e+00, best bound 5.504512036811e+00, gap 0.0000%
# Optimize a model with 71 rows, 210 columns and 446 nonzeros
# Variable types: 0 continuous, 210 integer (124 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 17 rows and 61 columns
# Presolve time: 0.00s
# Presolved: 54 rows, 149 columns, 327 nonzeros
# Variable types: 0 continuous, 149 integer (116 binary)
#
# Root relaxation: objective 7.277913e+00, 56 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.2779132    7.27791  0.00%     -    0s
#
# Explored 0 nodes (56 simplex iterations) in 0.14 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.27791 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.277913155691e+00, best bound 7.277913155691e+00, gap 0.0000%
# Optimize a model with 71 rows, 193 columns and 412 nonzeros
# Variable types: 0 continuous, 193 integer (107 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 23 rows and 75 columns
# Presolve time: 0.00s
# Presolved: 48 rows, 118 columns, 270 nonzeros
# Variable types: 0 continuous, 118 integer (84 binary)
#
# Root relaxation: objective 6.699800e+00, 45 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.6997996    6.69980  0.00%     -    0s
#
# Explored 0 nodes (45 simplex iterations) in 0.18 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.6998 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.699799636016e+00, best bound 6.699799636016e+00, gap 0.0000%
# Optimize a model with 71 rows, 201 columns and 428 nonzeros
# Variable types: 0 continuous, 201 integer (115 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 20 rows and 71 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 130 columns, 293 nonzeros
# Variable types: 0 continuous, 130 integer (90 binary)
#
# Root relaxation: objective 7.559730e+00, 51 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.5597300    7.55973  0.00%     -    0s
#
# Explored 0 nodes (51 simplex iterations) in 0.16 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.55973 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.559730044267e+00, best bound 7.559730044267e+00, gap 0.0000%
# Optimize a model with 71 rows, 213 columns and 452 nonzeros
# Variable types: 0 continuous, 213 integer (127 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 16 rows and 57 columns
# Presolve time: 0.00s
# Presolved: 55 rows, 156 columns, 348 nonzeros
# Variable types: 0 continuous, 156 integer (110 binary)
#
# Root relaxation: objective 7.273394e+00, 60 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.2733937    7.27339  0.00%     -    0s
#
# Explored 0 nodes (60 simplex iterations) in 0.19 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.27339 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.273393727011e+00, best bound 7.273393727011e+00, gap 0.0000%
# Optimize a model with 71 rows, 179 columns and 384 nonzeros
# Variable types: 0 continuous, 179 integer (93 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 23 rows and 63 columns
# Presolve time: 0.00s
# Presolved: 48 rows, 116 columns, 266 nonzeros
# Found heuristic solution: objective 2.7320955
# Variable types: 0 continuous, 116 integer (80 binary)
#
# Root relaxation: objective 6.407170e+00, 38 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.4071698    6.40717  0.00%     -    0s
#
# Explored 0 nodes (38 simplex iterations) in 0.17 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 6.40717 2.7321 0.435822
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.407169782633e+00, best bound 6.407169782633e+00, gap 0.0000%
# Optimize a model with 71 rows, 196 columns and 418 nonzeros
# Variable types: 0 continuous, 196 integer (110 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 17 rows and 52 columns
# Presolve time: 0.00s
# Presolved: 54 rows, 144 columns, 320 nonzeros
# Variable types: 0 continuous, 144 integer (102 binary)
#
# Root relaxation: objective 5.765399e+00, 57 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       5.7653988    5.76540  0.00%     -    0s
#
# Explored 0 nodes (57 simplex iterations) in 0.19 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 5.7654 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.765398833121e+00, best bound 5.765398833121e+00, gap 0.0000%
# Optimize a model with 71 rows, 213 columns and 452 nonzeros
# Variable types: 0 continuous, 213 integer (127 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 22 rows and 83 columns
# Presolve time: 0.00s
# Presolved: 49 rows, 130 columns, 297 nonzeros
# Variable types: 0 continuous, 130 integer (103 binary)
#
# Root relaxation: objective 4.911190e+00, 71 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       4.9111900    4.91119  0.00%     -    0s
#
# Explored 0 nodes (71 simplex iterations) in 0.17 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 4.91119 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.911190026090e+00, best bound 4.911190026090e+00, gap 0.0000%
# Optimize a model with 71 rows, 204 columns and 434 nonzeros
# Variable types: 0 continuous, 204 integer (118 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 18 rows and 67 columns
# Presolve time: 0.00s
# Presolved: 53 rows, 137 columns, 313 nonzeros
# Found heuristic solution: objective 3.3233296
# Variable types: 0 continuous, 137 integer (98 binary)
#
# Root relaxation: objective 7.067896e+00, 54 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.0678959    7.06790  0.00%     -    0s
#
# Explored 0 nodes (54 simplex iterations) in 0.16 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 7.0679 3.32333 0.453332
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.067895887872e+00, best bound 7.067895887872e+00, gap 0.0000%
# Optimize a model with 71 rows, 207 columns and 440 nonzeros
# Variable types: 0 continuous, 207 integer (121 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 23 rows and 73 columns
# Presolve time: 0.00s
# Presolved: 48 rows, 134 columns, 304 nonzeros
# Found heuristic solution: objective 2.8147373
# Variable types: 0 continuous, 134 integer (91 binary)
#
# Root relaxation: objective 7.983253e+00, 42 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.9832530    7.98325  0.00%     -    0s
#
# Explored 0 nodes (42 simplex iterations) in 0.14 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 7.98325 2.81474 0.184868
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.983252979695e+00, best bound 7.983252979695e+00, gap 0.0000%
# Optimize a model with 71 rows, 221 columns and 468 nonzeros
# Variable types: 0 continuous, 221 integer (135 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 18 rows and 55 columns
# Presolve time: 0.00s
# Presolved: 53 rows, 166 columns, 354 nonzeros
# Found heuristic solution: objective 3.0205314
# Variable types: 0 continuous, 166 integer (114 binary)
#
# Root relaxation: objective 8.247264e+00, 71 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       8.2472642    8.24726  0.00%     -    0s
#
# Explored 0 nodes (71 simplex iterations) in 0.20 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 8.24726 3.02053 0.157695
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.247264173913e+00, best bound 8.247264173913e+00, gap 0.0000%
# Optimize a model with 71 rows, 219 columns and 464 nonzeros
# Variable types: 0 continuous, 219 integer (133 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 30 rows and 94 columns
# Presolve time: 0.00s
# Presolved: 41 rows, 125 columns, 277 nonzeros
# Variable types: 0 continuous, 125 integer (95 binary)
#
# Root relaxation: objective 6.320614e+00, 48 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.3206138    6.32061  0.00%     -    0s
#
# Explored 0 nodes (48 simplex iterations) in 0.16 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.32061 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.320613810264e+00, best bound 6.320613810264e+00, gap 0.0000%
# Optimize a model with 71 rows, 190 columns and 406 nonzeros
# Variable types: 0 continuous, 190 integer (104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 23 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 48 rows, 125 columns, 284 nonzeros
# Found heuristic solution: objective 3.1052284
# Variable types: 0 continuous, 125 integer (89 binary)
#
# Root relaxation: objective 6.031415e+00, 54 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.0314146    6.03141  0.00%     -    0s
#
# Explored 0 nodes (54 simplex iterations) in 0.17 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 6.03141 3.10523 0.164
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.031414634257e+00, best bound 6.031414634257e+00, gap 0.0000%
# Optimize a model with 71 rows, 177 columns and 380 nonzeros
# Variable types: 0 continuous, 177 integer (91 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 32 rows and 97 columns
# Presolve time: 0.00s
# Presolved: 39 rows, 80 columns, 187 nonzeros
# Variable types: 0 continuous, 80 integer (48 binary)
#
# Root relaxation: objective 4.074324e+00, 32 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       4.0743244    4.07432  0.00%     -    0s
#
# Explored 0 nodes (32 simplex iterations) in 0.18 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 4.07432 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.074324426805e+00, best bound 4.074324426805e+00, gap 0.0000%
# Optimize a model with 71 rows, 205 columns and 436 nonzeros
# Variable types: 0 continuous, 205 integer (119 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 26 rows and 94 columns
# Presolve time: 0.00s
# Presolved: 45 rows, 111 columns, 250 nonzeros
# Variable types: 0 continuous, 111 integer (91 binary)
#
# Root relaxation: objective 4.499144e+00, 63 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       4.4991443    4.49914  0.00%     -    0s
#
# Explored 0 nodes (63 simplex iterations) in 0.18 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 4.49914 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.499144282719e+00, best bound 4.499144282719e+00, gap 0.0000%
# Optimize a model with 71 rows, 209 columns and 444 nonzeros
# Variable types: 0 continuous, 209 integer (123 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 22 rows and 82 columns
# Presolve time: 0.00s
# Presolved: 49 rows, 127 columns, 287 nonzeros
# Variable types: 0 continuous, 127 integer (95 binary)
#
# Root relaxation: objective 5.679344e+00, 63 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       5.6793438    5.67934  0.00%     -    0s
#
# Explored 0 nodes (63 simplex iterations) in 0.18 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 5.67934 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.679343814995e+00, best bound 5.679343814995e+00, gap 0.0000%
# Optimize a model with 71 rows, 199 columns and 424 nonzeros
# Variable types: 0 continuous, 199 integer (113 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 16 rows and 60 columns
# Presolve time: 0.00s
# Presolved: 55 rows, 139 columns, 315 nonzeros
# Variable types: 0 continuous, 139 integer (93 binary)
#
# Root relaxation: objective 7.774450e+00, 56 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.7744499    7.77445  0.00%     -    0s
#
# Explored 0 nodes (56 simplex iterations) in 0.18 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.77445 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.774449894658e+00, best bound 7.774449894658e+00, gap 0.0000%
# Optimize a model with 71 rows, 174 columns and 374 nonzeros
# Variable types: 0 continuous, 174 integer (88 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 22 rows and 59 columns
# Presolve time: 0.00s
# Presolved: 49 rows, 115 columns, 259 nonzeros
# Found heuristic solution: objective 3.1609147
# Variable types: 0 continuous, 115 integer (65 binary)
#
# Root relaxation: objective 7.883381e+00, 40 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.8833806    7.88338  0.00%     -    0s
# Explored 0 nodes (40 simplex iterations) in 0.19 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 7.88338 3.16091 0.321938
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.883380569309e+00, best bound 7.883380569309e+00, gap 0.0000%
# Optimize a model with 71 rows, 209 columns and 444 nonzeros
# Variable types: 0 continuous, 209 integer (123 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 18 rows and 60 columns
# Presolve time: 0.00s
# Presolved: 53 rows, 149 columns, 332 nonzeros
# Variable types: 0 continuous, 149 integer (102 binary)
#
# Root relaxation: objective 8.847415e+00, 45 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       8.8474146    8.84741  0.00%     -    0s
#
# Explored 0 nodes (45 simplex iterations) in 0.14 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 8.84741 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.847414638945e+00, best bound 8.847414638945e+00, gap 0.0000%
# Optimize a model with 71 rows, 185 columns and 396 nonzeros
# Variable types: 0 continuous, 185 integer (99 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 16 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 55 rows, 137 columns, 308 nonzeros
# Variable types: 0 continuous, 137 integer (93 binary)
#
# Root relaxation: objective 7.396044e+00, 32 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.3960436    7.39604  0.00%     -    0s
#
# Explored 0 nodes (32 simplex iterations) in 0.16 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.39604 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.396043564358e+00, best bound 7.396043564358e+00, gap 0.0000%
# Optimize a model with 71 rows, 180 columns and 386 nonzeros
# Variable types: 0 continuous, 180 integer (94 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 20 rows and 56 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 124 columns, 282 nonzeros
# Variable types: 0 continuous, 124 integer (86 binary)
#
# Root relaxation: objective 6.801757e+00, 42 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.8017566    6.80176  0.00%     -    0s
#
# Explored 0 nodes (42 simplex iterations) in 0.16 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.80176 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.801756601856e+00, best bound 6.801756601856e+00, gap 0.0000%
# Optimize a model with 71 rows, 194 columns and 414 nonzeros
# Variable types: 0 continuous, 194 integer (108 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 18 rows and 59 columns
# Presolve time: 0.00s
# Presolved: 53 rows, 135 columns, 307 nonzeros
# Variable types: 0 continuous, 135 integer (96 binary)
#
# Root relaxation: objective 6.126337e+00, 58 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.1263369    6.12634  0.00%     -    0s
#
# Explored 0 nodes (58 simplex iterations) in 0.16 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.12634 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.126336910931e+00, best bound 6.126336910931e+00, gap 0.0000%
# Optimize a model with 71 rows, 202 columns and 430 nonzeros
# Variable types: 0 continuous, 202 integer (116 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 18 rows and 54 columns
# Presolve time: 0.00s
# Presolved: 53 rows, 148 columns, 335 nonzeros
# Variable types: 0 continuous, 148 integer (108 binary)
#
# Root relaxation: objective 6.784682e+00, 66 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.7846816    6.78468  0.00%     -    0s
#
# Explored 0 nodes (66 simplex iterations) in 0.20 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.78468 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.784681586339e+00, best bound 6.784681586339e+00, gap 0.0000%
# Optimize a model with 71 rows, 195 columns and 416 nonzeros
# Variable types: 0 continuous, 195 integer (109 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 26 rows and 75 columns
# Presolve time: 0.00s
# Presolved: 45 rows, 120 columns, 270 nonzeros
# Variable types: 0 continuous, 120 integer (87 binary)
#
# Root relaxation: objective 6.515350e+00, 50 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.5153504    6.51535  0.00%     -    0s
#
# Explored 0 nodes (50 simplex iterations) in 0.12 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.51535 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.515350369510e+00, best bound 6.515350369510e+00, gap 0.0000%
# Optimize a model with 71 rows, 212 columns and 450 nonzeros
# Variable types: 0 continuous, 212 integer (126 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 18 rows and 62 columns
# Presolve time: 0.00s
# Presolved: 53 rows, 150 columns, 333 nonzeros
# ...
#
# *    0     0               0       6.3375903    6.33759  0.00%     -    0s
#
# Explored 0 nodes (39 simplex iterations) in 0.14 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.33759 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.337590326914e+00, best bound 6.337590326914e+00, gap 0.0000%
# Optimize a model with 71 rows, 188 columns and 402 nonzeros
# Variable types: 0 continuous, 188 integer (102 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 25 rows and 71 columns
# Presolve time: 0.00s
# Presolved: 46 rows, 117 columns, 261 nonzeros
# Variable types: 0 continuous, 117 integer (82 binary)
#
# Root relaxation: objective 4.996488e+00, 49 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       4.9964884    4.99649  0.00%     -    0s
#
# Explored 0 nodes (49 simplex iterations) in 0.13 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 4.99649 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.996488403271e+00, best bound 4.996488403271e+00, gap 0.0000%
# Optimize a model with 71 rows, 210 columns and 446 nonzeros
# Variable types: 0 continuous, 210 integer (124 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 20 rows and 66 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 144 columns, 324 nonzeros
# Variable types: 0 continuous, 144 integer (97 binary)
#
# Root relaxation: objective 7.351454e+00, 62 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.3514535    7.35145  0.00%     -    0s
#
# Explored 0 nodes (62 simplex iterations) in 0.12 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.35145 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.351453520800e+00, best bound 7.351453520800e+00, gap 0.0000%
# Optimize a model with 71 rows, 206 columns and 438 nonzeros
# Variable types: 0 continuous, 206 integer (120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 21 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 141 columns, 315 nonzeros
# Variable types: 0 continuous, 141 integer (95 binary)
#
# Root relaxation: objective 7.925401e+00, 61 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.9254006    7.92540  0.00%     -    0s
#
# Explored 0 nodes (61 simplex iterations) in 0.14 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.9254 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.925400596616e+00, best bound 7.925400596616e+00, gap 0.0000%
# Optimize a model with 71 rows, 195 columns and 416 nonzeros
# Variable types: 0 continuous, 195 integer (109 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 22 rows and 73 columns
# Presolve time: 0.00s
# Presolved: 49 rows, 122 columns, 269 nonzeros
# Variable types: 0 continuous, 122 integer (88 binary)
#
# Root relaxation: objective 6.270022e+00, 51 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.2700222    6.27002  0.00%     -    0s
#
# Explored 0 nodes (51 simplex iterations) in 0.14 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.27002 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.270022204424e+00, best bound 6.270022204424e+00, gap 0.0000%
# Optimize a model with 71 rows, 197 columns and 420 nonzeros
# Variable types: 0 continuous, 197 integer (111 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 21 rows and 64 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 133 columns, 306 nonzeros
# Variable types: 0 continuous, 133 integer (95 binary)
#
# Root relaxation: objective 6.228211e+00, 56 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.2282106    6.22821  0.00%     -    0s
#
# Explored 0 nodes (56 simplex iterations) in 0.13 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.22821 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.228210624107e+00, best bound 6.228210624107e+00, gap 0.0000%
# Optimize a model with 71 rows, 207 columns and 440 nonzeros
# Variable types: 0 continuous, 207 integer (121 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 16 rows and 57 columns
# Presolve time: 0.00s
# Presolved: 55 rows, 150 columns, 331 nonzeros
# Variable types: 0 continuous, 150 integer (115 binary)
#
# Root relaxation: objective 6.912709e+00, 78 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.9127091    6.91271  0.00%     -    0s
#
# Explored 0 nodes (78 simplex iterations) in 0.13 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.91271 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.912709078614e+00, best bound 6.912709078614e+00, gap 0.0000%
# Optimize a model with 71 rows, 182 columns and 390 nonzeros
# Variable types: 0 continuous, 182 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 27 rows and 73 columns
# Presolve time: 0.00s
# Presolved: 44 rows, 109 columns, 244 nonzeros
# Variable types: 0 continuous, 109 integer (68 binary)
#
# Root relaxation: objective 6.116643e+00, 31 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.1166435    6.11664  0.00%     -    0s
#
# Explored 0 nodes (31 simplex iterations) in 0.12 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.11664 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.116643468955e+00, best bound 6.116643468955e+00, gap 0.0000%
# Optimize a model with 71 rows, 190 columns and 406 nonzeros
# Variable types: 0 continuous, 190 integer (104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 26 rows and 75 columns
# Presolve time: 0.00s
# Presolved: 45 rows, 115 columns, 254 nonzeros
# Variable types: 0 continuous, 115 integer (82 binary)
#
# Root relaxation: objective 5.526860e+00, 46 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       5.5268599    5.52686  0.00%     -    0s
#
# Explored 0 nodes (46 simplex iterations) in 0.16 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 5.52686 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.526859947619e+00, best bound 5.526859947619e+00, gap 0.0000%
# Optimize a model with 71 rows, 209 columns and 444 nonzeros
# Variable types: 0 continuous, 209 integer (123 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 21 rows and 62 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 147 columns, 322 nonzeros
# Variable types: 0 continuous, 147 integer (110 binary)
#
# Root relaxation: objective 5.403606e+00, 87 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       5.4036062    5.40361  0.00%     -    0s
#
# Explored 0 nodes (87 simplex iterations) in 0.17 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 5.40361 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.403606222962e+00, best bound 5.403606222962e+00, gap 0.0000%
# Optimize a model with 71 rows, 202 columns and 430 nonzeros
# Variable types: 0 continuous, 202 integer (116 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 18 rows and 51 columns
# Presolve time: 0.00s
# Presolved: 53 rows, 151 columns, 338 nonzeros
# Variable types: 0 continuous, 151 integer (114 binary)
#
# Root relaxation: objective 6.991570e+00, 70 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.9915697    6.99157  0.00%     -    0s
#
# Explored 0 nodes (70 simplex iterations) in 0.14 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.99157 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.991569712263e+00, best bound 6.991569712263e+00, gap 0.0000%
# Optimize a model with 71 rows, 214 columns and 454 nonzeros
# Variable types: 0 continuous, 214 integer (128 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 9e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 22 rows and 74 columns
# Presolve time: 0.00s
# Presolved: 49 rows, 140 columns, 304 nonzeros
# Variable types: 0 continuous, 140 integer (104 binary)
#
# Root relaxation: objective 7.295824e+00, 71 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.2958238    7.29582  0.00%     -    0s
#
# Explored 0 nodes (71 simplex iterations) in 0.14 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 7.29582 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.295823848696e+00, best bound 7.295823848696e+00, gap 0.0000%
# Optimize a model with 71 rows, 207 columns and 440 nonzeros
# Variable types: 0 continuous, 207 integer (121 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 20 rows and 62 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 145 columns, 330 nonzeros
# Found heuristic solution: objective 3.1751526
# Variable types: 0 continuous, 145 integer (111 binary)
#
# Root relaxation: objective 7.057049e+00, 60 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       7.0570488    7.05705  0.00%     -    0s
#
# Explored 0 nodes (60 simplex iterations) in 0.15 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 7.05705 3.17515 0.372425
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.057048751770e+00, best bound 7.057048751770e+00, gap 0.0000%
# Optimize a model with 71 rows, 228 columns and 482 nonzeros
# Variable types: 0 continuous, 228 integer (142 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 14 rows and 55 columns
# Presolve time: 0.00s
# Presolved: 57 rows, 173 columns, 384 nonzeros
# Variable types: 0 continuous, 173 integer (128 binary)
#
# Root relaxation: objective 8.361371e+00, 60 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       8.3613708    8.36137  0.00%     -    0s
#
# Explored 0 nodes (60 simplex iterations) in 0.14 seconds
# Thread count was 4 (of 4 available processors)
# Solution count 2: 8.36137 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.361370750922e+00, best bound 8.361370750922e+00, gap 0.0000%
# Optimize a model with 71 rows, 182 columns and 390 nonzeros
# Variable types: 0 continuous, 182 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-03, 8e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 19 rows and 50 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 132 columns, 296 nonzeros
# Variable types: 0 continuous, 132 integer (87 binary)
#
# Root relaxation: objective 6.475734e+00, 57 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       6.4757336    6.47573  0.00%     -    0s
#
# Explored 0 nodes (57 simplex iterations) in 0.16 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 6.47573 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.475733583310e+00, best bound 6.475733583310e+00, gap 0.0000%
# Optimize a model with 71 rows, 178 columns and 382 nonzeros
# Variable types: 0 continuous, 178 integer (92 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e-03, 7e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 20 rows and 61 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 117 columns, 268 nonzeros
# Variable types: 0 continuous, 117 integer (89 binary)
#
# Root relaxation: objective 5.239400e+00, 44 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       5.2394001    5.23940  0.00%     -    0s
#
# Explored 0 nodes (44 simplex iterations) in 0.15 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 5.2394 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.239400092817e+00, best bound 5.239400092817e+00, gap 0.0000%

# %%
cols_icu = ['capacity'] + [str(d)+'_arrival_lost' for d in range(1,tot_days+1)] + [str(d)+'_obj' for d in range(1,tot_days+1)]
out_df_icu = pd.DataFrame(columns=cols_icu, index=I)

for i in I:
    out_df_icu.at[i, 'capacity'] = C_bar[i]
    for day in range(1,tot_days+1):       
        if A_icu[day][i] > 0:
            lost = 100*L_icu[day][i]/A_icu[day][i]
        else:
            lost = 0
        out_df_icu.at[i, str(day)+'_arrival_lost'] = lost
        obj = o[day]
        out_df_icu.at[i, str(day)+'_obj'] = obj

out_df_icu.to_excel("policyOPT_icu_output_N"+str(network)+".xlsx")
